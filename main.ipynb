# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

NODES = 32

class tarikModel4(nn.Module):
    def __init__(self, in_features=4, h1=NODES, h2=NODES, h3=NODES, h4=NODES, h5=NODES, h6=NODES, h7=NODES, h8=NODES, h9=NODES, h10=NODES, h11=NODES, h12=NODES, h13=NODES, h14=NODES, h15=NODES, h16=NODES,out_features=1):
        super().__init__()
        self.fc1 = nn.Linear(in_features, h1)
        self.fc2 = nn.Linear(h1, h2)
        self.fc3 = nn.Linear(h2,h3)
        self.fc4 = nn.Linear(h3,h4)
        self.fc5 = nn.Linear(NODES,NODES)
        self.fc6 = nn.Linear(NODES,NODES)
        self.fc7 = nn.Linear(NODES,NODES)
        self.fc8 = nn.Linear(NODES,NODES)
        self.fc9 = nn.Linear(NODES,NODES)
        self.fc10 = nn.Linear(NODES,NODES)
        self.fc11 = nn.Linear(NODES,NODES)
        self.fc12 = nn.Linear(NODES,NODES)
        self.fc13 = nn.Linear(NODES,NODES)
        self.fc14 = nn.Linear(NODES,NODES)
        self.fc15 = nn.Linear(NODES,NODES)
        self.fc16 = nn.Linear(NODES,NODES)
        self.out = nn.Linear(NODES, out_features)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = F.relu(self.fc5(x))
        x = F.relu(self.fc6(x))
        x = F.relu(self.fc7(x))
        x = F.relu(self.fc8(x))
        x = F.relu(self.fc9(x))
        x = F.relu(self.fc10(x))
        x = F.relu(self.fc11(x))
        x = F.relu(self.fc12(x))
        x = F.relu(self.fc13(x))
        x = F.relu(self.fc14(x))
        x = F.relu(self.fc15(x))
        x = F.relu(self.fc16(x))
        x = self.out(x)

        return x

#Use GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

X_train = pd.read_csv("data/X_train.csv")
X_test = pd.read_csv("data/X_test.csv")
y_train = pd.read_csv("data/y_train.csv")
y_test = pd.read_csv("data/y_test.csv")

#Convert X and y features to float tensors
X_train = torch.FloatTensor(X_train.values).to(device)
X_test  = torch.FloatTensor(X_test.values).to(device)
y_train = torch.FloatTensor(y_train.values).to(device)
y_test  = torch.FloatTensor(y_test.values).to(device)

model = tarikModel4().to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=0.0001)

epochs = 40000
losses =[]
for epoch in range(epochs):
    #model.train()

    # Forward pass
    y_pred = model(X_train)

    # Compute loss
    loss = criterion(y_pred, y_train)
    losses.append(loss.item())  # Convert tensor to float

    # Backprop and update
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # Print progress
    if (epoch+1) % 20 == 0:
        print(f"Epoch {epoch+1}/{epochs}, Loss = {loss.item():.4f}")

plt.plot(range(epochs), losses)
plt.ylabel("loss/error")
plt.xlabel('Epoch')
# plt.show()

#Save the Model
torch.save(model.state_dict(), "model.pt")
# Out:
# Using device: cuda
# Epoch 20/40000, Loss = 6072.5405
# Epoch 40/40000, Loss = 6069.6958
# Epoch 60/40000, Loss = 6066.9321
# Epoch 80/40000, Loss = 6063.8921
# Epoch 100/40000, Loss = 6060.1167
# Epoch 120/40000, Loss = 6053.7354
# Epoch 140/40000, Loss = 6026.9678
# Epoch 160/40000, Loss = 5891.7646
# Epoch 180/40000, Loss = 5240.3848
# Epoch 200/40000, Loss = 2642.4636
# Epoch 220/40000, Loss = 618.6612
# Epoch 240/40000, Loss = 431.9132
# Epoch 260/40000, Loss = 404.2697
# Epoch 280/40000, Loss = 399.3906
# Epoch 300/40000, Loss = 395.0233
# Epoch 320/40000, Loss = 390.1982
# Epoch 340/40000, Loss = 386.1146
# Epoch 360/40000, Loss = 382.2788
# Epoch 380/40000, Loss = 378.3606
# Epoch 400/40000, Loss = 374.3093
# Epoch 420/40000, Loss = 370.0827
# Epoch 440/40000, Loss = 365.6729
# Epoch 460/40000, Loss = 361.0580
# Epoch 480/40000, Loss = 356.0911
# Epoch 500/40000, Loss = 349.9810
# Epoch 520/40000, Loss = 342.4694
# Epoch 540/40000, Loss = 332.7981
# Epoch 560/40000, Loss = 321.6837
# Epoch 580/40000, Loss = 309.5278
# Epoch 600/40000, Loss = 296.1675
# Epoch 620/40000, Loss = 281.5626
# Epoch 640/40000, Loss = 265.7747
# Epoch 660/40000, Loss = 249.1535
# Epoch 680/40000, Loss = 231.2964
# Epoch 700/40000, Loss = 210.3657
# Epoch 720/40000, Loss = 187.6137
# Epoch 740/40000, Loss = 160.8135
# Epoch 760/40000, Loss = 131.5605
# Epoch 780/40000, Loss = 102.3574
# Epoch 800/40000, Loss = 75.8969
# Epoch 820/40000, Loss = 53.6334
# Epoch 840/40000, Loss = 36.8741
# Epoch 860/40000, Loss = 25.3475
# Epoch 880/40000, Loss = 19.1976
# Epoch 900/40000, Loss = 16.3326
# Epoch 920/40000, Loss = 15.1813
# Epoch 940/40000, Loss = 14.7542
# Epoch 960/40000, Loss = 14.5834
# Epoch 980/40000, Loss = 14.4987
# Epoch 1000/40000, Loss = 14.4459
# Epoch 1020/40000, Loss = 14.4082
# Epoch 1040/40000, Loss = 14.3786
# Epoch 1060/40000, Loss = 14.3541
# Epoch 1080/40000, Loss = 14.3329
# Epoch 1100/40000, Loss = 14.3138
# Epoch 1120/40000, Loss = 14.2961
# Epoch 1140/40000, Loss = 14.2794
# Epoch 1160/40000, Loss = 14.2627
# Epoch 1180/40000, Loss = 14.2478
# Epoch 1200/40000, Loss = 14.2328
# Epoch 1220/40000, Loss = 14.2180
# Epoch 1240/40000, Loss = 14.2040
# Epoch 1260/40000, Loss = 14.1907
# Epoch 1280/40000, Loss = 14.1778
# Epoch 1300/40000, Loss = 14.1651
# Epoch 1320/40000, Loss = 14.1528
# Epoch 1340/40000, Loss = 14.1409
# Epoch 1360/40000, Loss = 14.1292
# Epoch 1380/40000, Loss = 14.1173
# Epoch 1400/40000, Loss = 14.1052
# Epoch 1420/40000, Loss = 14.0929
# Epoch 1440/40000, Loss = 14.0802
# Epoch 1460/40000, Loss = 14.0672
# Epoch 1480/40000, Loss = 14.0538
# Epoch 1500/40000, Loss = 14.0399
# Epoch 1520/40000, Loss = 14.0255
# Epoch 1540/40000, Loss = 14.0103
# Epoch 1560/40000, Loss = 13.9935
# Epoch 1580/40000, Loss = 13.9751
# Epoch 1600/40000, Loss = 13.9552
# Epoch 1620/40000, Loss = 13.9341
# Epoch 1640/40000, Loss = 13.9117
# Epoch 1660/40000, Loss = 13.8890
# Epoch 1680/40000, Loss = 13.8659
# Epoch 1700/40000, Loss = 13.8417
# Epoch 1720/40000, Loss = 13.8157
# Epoch 1740/40000, Loss = 13.7892
# Epoch 1760/40000, Loss = 13.7624
# Epoch 1780/40000, Loss = 13.7344
# Epoch 1800/40000, Loss = 13.7037
# Epoch 1820/40000, Loss = 13.6689
# Epoch 1840/40000, Loss = 13.6299
# Epoch 1860/40000, Loss = 13.5831
# Epoch 1880/40000, Loss = 13.5278
# Epoch 1900/40000, Loss = 13.4655
# Epoch 1920/40000, Loss = 13.4000
# Epoch 1940/40000, Loss = 13.3326
# Epoch 1960/40000, Loss = 13.2646
# Epoch 1980/40000, Loss = 13.2019
# Epoch 2000/40000, Loss = 13.1477
# Epoch 2020/40000, Loss = 13.1064
# Epoch 2040/40000, Loss = 13.0770
# Epoch 2060/40000, Loss = 13.0559
# Epoch 2080/40000, Loss = 13.0401
# Epoch 2100/40000, Loss = 13.0270
# Epoch 2120/40000, Loss = 13.0156
# Epoch 2140/40000, Loss = 13.0053
# Epoch 2160/40000, Loss = 12.9957
# Epoch 2180/40000, Loss = 12.9868
# Epoch 2200/40000, Loss = 12.9782
# Epoch 2220/40000, Loss = 12.9699
# Epoch 2240/40000, Loss = 12.9618
# Epoch 2260/40000, Loss = 12.9539
# Epoch 2280/40000, Loss = 12.9461
# Epoch 2300/40000, Loss = 12.9383
# Epoch 2320/40000, Loss = 12.9307
# Epoch 2340/40000, Loss = 12.9231
# Epoch 2360/40000, Loss = 12.9157
# Epoch 2380/40000, Loss = 12.9083
# Epoch 2400/40000, Loss = 12.9010
# Epoch 2420/40000, Loss = 12.8937
# Epoch 2440/40000, Loss = 12.8865
# Epoch 2460/40000, Loss = 12.8793
# Epoch 2480/40000, Loss = 12.8722
# Epoch 2500/40000, Loss = 12.8651
# Epoch 2520/40000, Loss = 12.8581
# Epoch 2540/40000, Loss = 12.8511
# Epoch 2560/40000, Loss = 12.8441
# Epoch 2580/40000, Loss = 12.8371
# Epoch 2600/40000, Loss = 12.8302
# Epoch 2620/40000, Loss = 12.8233
# Epoch 2640/40000, Loss = 12.8164
# Epoch 2660/40000, Loss = 12.8096
# Epoch 2680/40000, Loss = 12.8028
# Epoch 2700/40000, Loss = 12.7959
# Epoch 2720/40000, Loss = 12.7891
# Epoch 2740/40000, Loss = 12.7823
# Epoch 2760/40000, Loss = 12.7756
# Epoch 2780/40000, Loss = 12.7688
# Epoch 2800/40000, Loss = 12.7621
# Epoch 2820/40000, Loss = 12.7554
# Epoch 2840/40000, Loss = 12.7487
# Epoch 2860/40000, Loss = 12.7420
# Epoch 2880/40000, Loss = 12.7353
# Epoch 2900/40000, Loss = 12.7286
# Epoch 2920/40000, Loss = 12.7219
# Epoch 2940/40000, Loss = 12.7152
# Epoch 2960/40000, Loss = 12.7086
# Epoch 2980/40000, Loss = 12.7019
# Epoch 3000/40000, Loss = 12.6952
# Epoch 3020/40000, Loss = 12.6885
# Epoch 3040/40000, Loss = 12.6818
# Epoch 3060/40000, Loss = 12.6752
# Epoch 3080/40000, Loss = 12.6685
# Epoch 3100/40000, Loss = 12.6618
# Epoch 3120/40000, Loss = 12.6552
# Epoch 3140/40000, Loss = 12.6485
# Epoch 3160/40000, Loss = 12.6418
# Epoch 3180/40000, Loss = 12.6351
# Epoch 3200/40000, Loss = 12.6284
# Epoch 3220/40000, Loss = 12.6216
# Epoch 3240/40000, Loss = 12.6149
# Epoch 3260/40000, Loss = 12.6082
# Epoch 3280/40000, Loss = 12.6014
# Epoch 3300/40000, Loss = 12.5946
# Epoch 3320/40000, Loss = 12.5878
# Epoch 3340/40000, Loss = 12.5810
# Epoch 3360/40000, Loss = 12.5741
# Epoch 3380/40000, Loss = 12.5673
# Epoch 3400/40000, Loss = 12.5604
# Epoch 3420/40000, Loss = 12.5536
# Epoch 3440/40000, Loss = 12.5467
# Epoch 3460/40000, Loss = 12.5398
# Epoch 3480/40000, Loss = 12.5329
# Epoch 3500/40000, Loss = 12.5259
# Epoch 3520/40000, Loss = 12.5189
# Epoch 3540/40000, Loss = 12.5119
# Epoch 3560/40000, Loss = 12.5050
# Epoch 3580/40000, Loss = 12.4980
# Epoch 3600/40000, Loss = 12.4909
# Epoch 3620/40000, Loss = 12.4839
# Epoch 3640/40000, Loss = 12.4767
# Epoch 3660/40000, Loss = 12.4696
# Epoch 3680/40000, Loss = 12.4624
# Epoch 3700/40000, Loss = 12.4551
# Epoch 3720/40000, Loss = 12.4478
# Epoch 3740/40000, Loss = 12.4405
# Epoch 3760/40000, Loss = 12.4333
# Epoch 3780/40000, Loss = 12.4259
# Epoch 3800/40000, Loss = 12.4186
# Epoch 3820/40000, Loss = 12.4112
# Epoch 3840/40000, Loss = 12.4038
# Epoch 3860/40000, Loss = 12.3964
# Epoch 3880/40000, Loss = 12.3889
# Epoch 3900/40000, Loss = 12.3813
# Epoch 3920/40000, Loss = 12.3738
# Epoch 3940/40000, Loss = 12.3662
# Epoch 3960/40000, Loss = 12.3585
# Epoch 3980/40000, Loss = 12.3508
# Epoch 4000/40000, Loss = 12.3430
# Epoch 4020/40000, Loss = 12.3351
# Epoch 4040/40000, Loss = 12.3270
# Epoch 4060/40000, Loss = 12.3200
# Epoch 4080/40000, Loss = 12.3112
# Epoch 4100/40000, Loss = 12.3032
# Epoch 4120/40000, Loss = 12.2953
# Epoch 4140/40000, Loss = 12.2873
# Epoch 4160/40000, Loss = 12.2793
# Epoch 4180/40000, Loss = 12.2716
# Epoch 4200/40000, Loss = 12.2632
# Epoch 4220/40000, Loss = 12.2549
# Epoch 4240/40000, Loss = 12.2480
# Epoch 4260/40000, Loss = 12.2385
# Epoch 4280/40000, Loss = 12.2304
# Epoch 4300/40000, Loss = 12.2220
# Epoch 4320/40000, Loss = 12.2145
# Epoch 4340/40000, Loss = 12.2055
# Epoch 4360/40000, Loss = 12.1971
# Epoch 4380/40000, Loss = 12.1884
# Epoch 4400/40000, Loss = 12.1821
# Epoch 4420/40000, Loss = 12.1716
# Epoch 4440/40000, Loss = 12.1627
# Epoch 4460/40000, Loss = 12.1542
# Epoch 4480/40000, Loss = 12.1454
# Epoch 4500/40000, Loss = 12.1365
# Epoch 4520/40000, Loss = 12.1278
# Epoch 4540/40000, Loss = 12.1189
# Epoch 4560/40000, Loss = 12.1108
# Epoch 4580/40000, Loss = 12.1009
# Epoch 4600/40000, Loss = 12.0920
# Epoch 4620/40000, Loss = 12.0834
# Epoch 4640/40000, Loss = 12.0743
# Epoch 4660/40000, Loss = 12.0645
# Epoch 4680/40000, Loss = 12.0551
# Epoch 4700/40000, Loss = 12.0468
# Epoch 4720/40000, Loss = 12.0368
# Epoch 4740/40000, Loss = 12.0271
# Epoch 4760/40000, Loss = 12.0174
# Epoch 4780/40000, Loss = 12.0097
# Epoch 4800/40000, Loss = 11.9982
# Epoch 4820/40000, Loss = 11.9890
# Epoch 4840/40000, Loss = 11.9785
# Epoch 4860/40000, Loss = 11.9713
# Epoch 4880/40000, Loss = 11.9591
# Epoch 4900/40000, Loss = 11.9487
# Epoch 4920/40000, Loss = 11.9390
# Epoch 4940/40000, Loss = 11.9283
# Epoch 4960/40000, Loss = 11.9188
# Epoch 4980/40000, Loss = 11.9076
# Epoch 5000/40000, Loss = 11.8988
# Epoch 5020/40000, Loss = 11.8868
# Epoch 5040/40000, Loss = 11.8760
# Epoch 5060/40000, Loss = 11.8668
# Epoch 5080/40000, Loss = 11.8551
# Epoch 5100/40000, Loss = 11.8438
# Epoch 5120/40000, Loss = 11.8327
# Epoch 5140/40000, Loss = 11.8226
# Epoch 5160/40000, Loss = 11.8112
# Epoch 5180/40000, Loss = 11.7989
# Epoch 5200/40000, Loss = 11.7906
# Epoch 5220/40000, Loss = 11.7765
# Epoch 5240/40000, Loss = 11.7650
# Epoch 5260/40000, Loss = 11.7528
# Epoch 5280/40000, Loss = 11.7437
# Epoch 5300/40000, Loss = 11.7292
# Epoch 5320/40000, Loss = 11.7171
# Epoch 5340/40000, Loss = 11.7049
# Epoch 5360/40000, Loss = 11.6962
# Epoch 5380/40000, Loss = 11.6801
# Epoch 5400/40000, Loss = 11.6683
# Epoch 5420/40000, Loss = 11.6556
# Epoch 5440/40000, Loss = 11.6425
# Epoch 5460/40000, Loss = 11.6296
# Epoch 5480/40000, Loss = 11.6162
# Epoch 5500/40000, Loss = 11.6050
# Epoch 5520/40000, Loss = 11.5910
# Epoch 5540/40000, Loss = 11.5762
# Epoch 5560/40000, Loss = 11.5577
# Epoch 5580/40000, Loss = 11.4656
# Epoch 5600/40000, Loss = 11.4216
# Epoch 5620/40000, Loss = 11.3949
# Epoch 5640/40000, Loss = 11.3692
# Epoch 5660/40000, Loss = 11.3443
# Epoch 5680/40000, Loss = 11.3195
# Epoch 5700/40000, Loss = 11.2957
# Epoch 5720/40000, Loss = 11.2719
# Epoch 5740/40000, Loss = 11.2473
# Epoch 5760/40000, Loss = 11.2206
# Epoch 5780/40000, Loss = 11.2057
# Epoch 5800/40000, Loss = 11.1670
# Epoch 5820/40000, Loss = 11.1404
# Epoch 5840/40000, Loss = 11.1165
# Epoch 5860/40000, Loss = 11.0927
# Epoch 5880/40000, Loss = 11.0669
# Epoch 5900/40000, Loss = 11.0432
# Epoch 5920/40000, Loss = 11.0243
# Epoch 5940/40000, Loss = 10.9937
# Epoch 5960/40000, Loss = 10.9677
# Epoch 5980/40000, Loss = 10.9425
# Epoch 6000/40000, Loss = 10.9312
# Epoch 6020/40000, Loss = 10.8930
# Epoch 6040/40000, Loss = 10.8665
# Epoch 6060/40000, Loss = 10.8403
# Epoch 6080/40000, Loss = 10.8139
# Epoch 6100/40000, Loss = 10.8206
# Epoch 6120/40000, Loss = 10.7637
# Epoch 6140/40000, Loss = 10.7352
# Epoch 6160/40000, Loss = 10.7076
# Epoch 6180/40000, Loss = 10.6801
# Epoch 6200/40000, Loss = 10.6528
# Epoch 6220/40000, Loss = 10.6297
# Epoch 6240/40000, Loss = 10.5969
# Epoch 6260/40000, Loss = 10.5683
# Epoch 6280/40000, Loss = 10.5390
# Epoch 6300/40000, Loss = 10.5447
# Epoch 6320/40000, Loss = 10.4842
# Epoch 6340/40000, Loss = 10.4518
# Epoch 6360/40000, Loss = 10.4214
# Epoch 6380/40000, Loss = 10.3970
# Epoch 6400/40000, Loss = 10.3676
# Epoch 6420/40000, Loss = 10.3307
# Epoch 6440/40000, Loss = 10.2996
# Epoch 6460/40000, Loss = 10.2711
# Epoch 6480/40000, Loss = 10.2367
# Epoch 6500/40000, Loss = 10.2061
# Epoch 6520/40000, Loss = 10.1782
# Epoch 6540/40000, Loss = 10.1406
# Epoch 6560/40000, Loss = 10.1150
# Epoch 6580/40000, Loss = 10.0755
# Epoch 6600/40000, Loss = 10.0602
# Epoch 6620/40000, Loss = 10.0175
# Epoch 6640/40000, Loss = 9.9759
# Epoch 6660/40000, Loss = 9.9422
# Epoch 6680/40000, Loss = 9.9082
# Epoch 6700/40000, Loss = 9.8752
# Epoch 6720/40000, Loss = 9.8497
# Epoch 6740/40000, Loss = 9.8080
# Epoch 6760/40000, Loss = 9.7695
# Epoch 6780/40000, Loss = 9.7335
# Epoch 6800/40000, Loss = 9.7523
# Epoch 6820/40000, Loss = 9.6693
# Epoch 6840/40000, Loss = 9.6261
# Epoch 6860/40000, Loss = 9.5889
# Epoch 6880/40000, Loss = 9.5912
# Epoch 6900/40000, Loss = 9.5160
# Epoch 6920/40000, Loss = 9.4760
# Epoch 6940/40000, Loss = 9.4377
# Epoch 6960/40000, Loss = 9.4259
# Epoch 6980/40000, Loss = 9.3699
# Epoch 7000/40000, Loss = 9.3233
# Epoch 7020/40000, Loss = 9.2832
# Epoch 7040/40000, Loss = 9.2434
# Epoch 7060/40000, Loss = 9.2034
# Epoch 7080/40000, Loss = 9.2497
# Epoch 7100/40000, Loss = 9.1251
# Epoch 7120/40000, Loss = 9.0874
# Epoch 7140/40000, Loss = 9.0464
# Epoch 7160/40000, Loss = 9.0062
# Epoch 7180/40000, Loss = 8.9651
# Epoch 7200/40000, Loss = 8.9233
# Epoch 7220/40000, Loss = 8.8814
# Epoch 7240/40000, Loss = 8.9233
# Epoch 7260/40000, Loss = 8.7996
# Epoch 7280/40000, Loss = 8.7563
# Epoch 7300/40000, Loss = 8.7136
# Epoch 7320/40000, Loss = 8.6700
# Epoch 7340/40000, Loss = 8.6290
# Epoch 7360/40000, Loss = 8.5917
# Epoch 7380/40000, Loss = 8.5384
# Epoch 7400/40000, Loss = 8.4996
# Epoch 7420/40000, Loss = 8.4468
# Epoch 7440/40000, Loss = 8.4058
# Epoch 7460/40000, Loss = 8.3674
# Epoch 7480/40000, Loss = 8.3135
# Epoch 7500/40000, Loss = 8.2666
# Epoch 7520/40000, Loss = 8.2450
# Epoch 7540/40000, Loss = 8.1750
# Epoch 7560/40000, Loss = 8.1247
# Epoch 7580/40000, Loss = 8.0987
# Epoch 7600/40000, Loss = 8.0303
# Epoch 7620/40000, Loss = 7.9821
# Epoch 7640/40000, Loss = 7.9770
# Epoch 7660/40000, Loss = 7.8891
# Epoch 7680/40000, Loss = 7.8303
# Epoch 7700/40000, Loss = 7.8246
# Epoch 7720/40000, Loss = 7.7316
# Epoch 7740/40000, Loss = 7.6809
# Epoch 7760/40000, Loss = 7.6311
# Epoch 7780/40000, Loss = 7.7261
# Epoch 7800/40000, Loss = 7.5340
# Epoch 7820/40000, Loss = 7.4883
# Epoch 7840/40000, Loss = 7.4328
# Epoch 7860/40000, Loss = 7.3817
# Epoch 7880/40000, Loss = 7.3656
# Epoch 7900/40000, Loss = 7.2846
# Epoch 7920/40000, Loss = 7.2296
# Epoch 7940/40000, Loss = 7.1797
# Epoch 7960/40000, Loss = 7.1427
# Epoch 7980/40000, Loss = 7.0807
# Epoch 8000/40000, Loss = 7.0241
# Epoch 8020/40000, Loss = 6.9729
# Epoch 8040/40000, Loss = 6.9549
# Epoch 8060/40000, Loss = 6.8871
# Epoch 8080/40000, Loss = 6.8205
# Epoch 8100/40000, Loss = 6.7684
# Epoch 8120/40000, Loss = 6.7223
# Epoch 8140/40000, Loss = 6.7559
# Epoch 8160/40000, Loss = 6.6214
# Epoch 8180/40000, Loss = 6.5662
# Epoch 8200/40000, Loss = 6.5144
# Epoch 8220/40000, Loss = 6.6262

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#Use GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

X_train = pd.read_csv("data/X_train.csv")
X_test = pd.read_csv("data/X_test.csv")
y_train = pd.read_csv("data/y_train.csv")
y_test = pd.read_csv("data/y_test.csv")

#Convert X and y features to float tensors
X_train = torch.FloatTensor(X_train.values).to(device)
X_test  = torch.FloatTensor(X_test.values).to(device)
y_train = torch.FloatTensor(y_train.values).to(device)
y_test  = torch.FloatTensor(y_test.values).to(device)

model = tarikModel4().to(device)

model.load_state_dict(torch.load("model.pt"))

criterion = nn.MSELoss()

with torch.no_grad():
    y_eval = model.forward(X_test)
    loss = criterion(y_eval, y_test)

# Print the MSE
print(f"Mean Squared Error on Test Set: {loss.item():.4f}")

amount = 0
withinFivePercent = 0
withinOnePercent = 0
with torch.no_grad():
    for i,data in enumerate(X_test):
        amount += 1
        y_val = model.forward(data)
        #print(str(y_val.item()) + "F is the predicted data the real data is " + str(y_test[i].item()) + "F the difference between the actual and predicted " + str(y_test[i].item() - y_val.item()) + "F")

        if abs(((y_val.item() - y_test[i].item())*100)/(y_test[i].item())) >= 5:
            print(str(y_val.item()) + "F is the predicted data the real data is " + str(y_test[i].item()) + "F the difference between the actual and predicted " + str(y_test[i].item() - y_val.item()) + "F")
            withinFivePercent+=1
        if abs(((y_val.item() - y_test[i].item())*100)/(y_test[i].item())) >= 1:
            print(str(y_val.item()) + "F is the predicted data the real data is " + str(y_test[i].item()) + "F the difference between the actual and predicted " + str(y_test[i].item() - y_val.item()) + "F")
            withinOnePercent+=1
print("Training data amount: " + str(amount))
print(str(withinFivePercent) + " is outside of 5% (" + str(withinFivePercent*100/amount) + "%)")
print(str(withinOnePercent) + " is outside of 1% (" + str(withinOnePercent*100/amount) + "%)")
print(str(loss.item()) + " is the MSE")
# Out:
# Using device: cuda
# Mean Squared Error on Test Set: 1.3518
# 79.29951477050781F is the predicted data the real data is 78.19999694824219F the difference between the actual and predicted -1.099517822265625F
# 74.43909454345703F is the predicted data the real data is 73.4000015258789F the difference between the actual and predicted -1.039093017578125F
# 77.87052154541016F is the predicted data the real data is 76.9000015258789F the difference between the actual and predicted -0.97052001953125F
# 78.15848541259766F is the predicted data the real data is 77.19999694824219F the difference between the actual and predicted -0.9584884643554688F
# 71.78705596923828F is the predicted data the real data is 72.5999984741211F the difference between the actual and predicted 0.8129425048828125F
# 76.7823257446289F is the predicted data the real data is 75.9000015258789F the difference between the actual and predicted -0.88232421875F
# 77.76034545898438F is the predicted data the real data is 76.0999984741211F the difference between the actual and predicted -1.6603469848632812F
# 77.214111328125F is the predicted data the real data is 75.69999694824219F the difference between the actual and predicted -1.5141143798828125F
# 75.5118637084961F is the predicted data the real data is 76.69999694824219F the difference between the actual and predicted 1.1881332397460938F
# 78.5473861694336F is the predicted data the real data is 77.4000015258789F the difference between the actual and predicted -1.1473846435546875F
# 74.85143280029297F is the predicted data the real data is 73.4000015258789F the difference between the actual and predicted -1.4514312744140625F
# 76.95919036865234F is the predicted data the real data is 75.69999694824219F the difference between the actual and predicted -1.2591934204101562F
# 81.7420425415039F is the predicted data the real data is 80.69999694824219F the difference between the actual and predicted -1.0420455932617188F
# 77.50537109375F is the predicted data the real data is 76.4000015258789F the difference between the actual and predicted -1.1053695678710938F
# 78.08320617675781F is the predicted data the real data is 77.30000305175781F the difference between the actual and predicted -0.783203125F
# 67.1004638671875F is the predicted data the real data is 69.80000305175781F the difference between the actual and predicted 2.6995391845703125F
# 69.89673614501953F is the predicted data the real data is 68.30000305175781F the difference between the actual and predicted -1.5967330932617188F
# 76.28288269042969F is the predicted data the real data is 77.0999984741211F the difference between the actual and predicted 0.8171157836914062F
# 75.52088928222656F is the predicted data the real data is 76.5F the difference between the actual and predicted 0.9791107177734375F
# 79.92727661132812F is the predicted data the real data is 79.0999984741211F the difference between the actual and predicted -0.8272781372070312F
# 78.97212982177734F is the predicted data the real data is 76.5F the difference between the actual and predicted -2.4721298217773438F
# 88.60604095458984F is the predicted data the real data is 87.4000015258789F the difference between the actual and predicted -1.2060394287109375F
# 78.49236297607422F is the predicted data the real data is 77.4000015258789F the difference between the actual and predicted -1.0923614501953125F
# 82.72978210449219F is the predicted data the real data is 84.0999984741211F the difference between the actual and predicted 1.3702163696289062F
# 74.72179412841797F is the predicted data the real data is 73.4000015258789F the difference between the actual and predicted -1.3217926025390625F
# 82.9722671508789F is the predicted data the real data is 84.0999984741211F the difference between the actual and predicted 1.1277313232421875F
# 78.75928497314453F is the predicted data the real data is 77.5999984741211F the difference between the actual and predicted -1.1592864990234375F
# 74.42701721191406F is the predicted data the real data is 73.30000305175781F the difference between the actual and predicted -1.12701416015625F
# 76.76631927490234F is the predicted data the real data is 78.0F the difference between the actual and predicted 1.2336807250976562F
# 76.70838165283203F is the predicted data the real data is 77.5999984741211F the difference between the actual and predicted 0.8916168212890625F
# 72.37389373779297F is the predicted data the real data is 70.4000015258789F the difference between the actual and predicted -1.9738922119140625F
# 83.23384857177734F is the predicted data the real data is 81.9000015258789F the difference between the actual and predicted -1.3338470458984375F
# 81.73745727539062F is the predicted data the real data is 80.30000305175781F the difference between the actual and predicted -1.4374542236328125F
# 76.92823028564453F is the predicted data the real data is 75.5999984741211F the difference between the actual and predicted -1.3282318115234375F
# 75.83789825439453F is the predicted data the real data is 74.4000015258789F the difference between the actual and predicted -1.437896728515625F
# 71.06111907958984F is the predicted data the real data is 69.80000305175781F the difference between the actual and predicted -1.2611160278320312F
# 79.39940643310547F is the predicted data the real data is 78.5999984741211F the difference between the actual and predicted -0.799407958984375F
# 76.6738510131836F is the predicted data the real data is 75.5999984741211F the difference between the actual and predicted -1.0738525390625F
# 79.67284393310547F is the predicted data the real data is 78.80000305175781F the difference between the actual and predicted -0.8728408813476562F
# 81.7254867553711F is the predicted data the real data is 80.19999694824219F the difference between the actual and predicted -1.5254898071289062F
# 76.32901763916016F is the predicted data the real data is 75.0999984741211F the difference between the actual and predicted -1.2290191650390625F
# 76.81654357910156F is the predicted data the real data is 76.0F the difference between the actual and predicted -0.8165435791015625F
# 73.72647857666016F is the predicted data the real data is 72.80000305175781F the difference between the actual and predicted -0.9264755249023438F
# 85.15351104736328F is the predicted data the real data is 86.4000015258789F the difference between the actual and predicted 1.246490478515625F
# 78.44635772705078F is the predicted data the real data is 77.4000015258789F the difference between the actual and predicted -1.046356201171875F
# 70.7244644165039F is the predicted data the real data is 70.0F the difference between the actual and predicted -0.7244644165039062F
# 76.72310638427734F is the predicted data the real data is 75.5F the difference between the actual and predicted -1.2231063842773438F
# 89.59175872802734F is the predicted data the real data is 87.19999694824219F the difference between the actual and predicted -2.3917617797851562F
# 80.0566177368164F is the predicted data the real data is 78.0999984741211F the difference between the actual and predicted -1.9566192626953125F
# 80.27656555175781F is the predicted data the real data is 78.0F the difference between the actual and predicted -2.2765655517578125F
# 76.8355712890625F is the predicted data the real data is 75.9000015258789F the difference between the actual and predicted -0.9355697631835938F
# 80.23133087158203F is the predicted data the real data is 78.69999694824219F the difference between the actual and predicted -1.5313339233398438F
# 80.75920867919922F is the predicted data the real data is 79.80000305175781F the difference between the actual and predicted -0.9592056274414062F
# 68.48092651367188F is the predicted data the real data is 67.5999984741211F the difference between the actual and predicted -0.8809280395507812F
# 80.11858367919922F is the predicted data the real data is 78.9000015258789F the difference between the actual and predicted -1.2185821533203125F
# 73.343505859375F is the predicted data the real data is 71.9000015258789F the difference between the actual and predicted -1.4435043334960938F
# 82.44639587402344F is the predicted data the real data is 83.30000305175781F the difference between the actual and predicted 0.853607177734375F
# 77.22406005859375F is the predicted data the real data is 75.69999694824219F the difference between the actual and predicted -1.5240631103515625F
# 82.70187377929688F is the predicted data the real data is 81.5F the difference between the actual and predicted -1.201873779296875F
# 74.60321807861328F is the predicted data the real data is 73.0F the difference between the actual and predicted -1.6032180786132812F
# 77.7558364868164F is the predicted data the real data is 76.9000015258789F the difference between the actual and predicted -0.8558349609375F
# 69.89407348632812F is the predicted data the real data is 70.69999694824219F the difference between the actual and predicted 0.8059234619140625F
# <ipython-input-3-59e18391f42c>:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("model.pt"))
# 73.74217987060547F is the predicted data the real data is 74.5F the difference between the actual and predicted 0.7578201293945312F
# 78.76477813720703F is the predicted data the real data is 77.9000015258789F the difference between the actual and predicted -0.864776611328125F
# 77.09652709960938F is the predicted data the real data is 75.69999694824219F the difference between the actual and predicted -1.3965301513671875F
# 77.06148529052734F is the predicted data the real data is 76.0999984741211F the difference between the actual and predicted -0.96148681640625F
# 71.8946304321289F is the predicted data the real data is 70.9000015258789F the difference between the actual and predicted -0.99462890625F
# 85.06140899658203F is the predicted data the real data is 83.5999984741211F the difference between the actual and predicted -1.4614105224609375F
# 74.46517944335938F is the predicted data the real data is 72.4000015258789F the difference between the actual and predicted -2.0651779174804688F
# 82.5155258178711F is the predicted data the real data is 81.4000015258789F the difference between the actual and predicted -1.1155242919921875F
# 79.62957000732422F is the predicted data the real data is 78.80000305175781F the difference between the actual and predicted -0.8295669555664062F
# 77.35005187988281F is the predicted data the real data is 75.69999694824219F the difference between the actual and predicted -1.650054931640625F
# 80.8107681274414F is the predicted data the real data is 78.5999984741211F the difference between the actual and predicted -2.2107696533203125F
# 75.94764709472656F is the predicted data the real data is 74.0999984741211F the difference between the actual and predicted -1.8476486206054688F
# 77.51803588867188F is the predicted data the real data is 75.9000015258789F the difference between the actual and predicted -1.6180343627929688F
# 75.6495361328125F is the predicted data the real data is 74.4000015258789F the difference between the actual and predicted -1.2495346069335938F
# 80.5361099243164F is the predicted data the real data is 78.5999984741211F the difference between the actual and predicted -1.9361114501953125F
# 78.46968841552734F is the predicted data the real data is 80.5F the difference between the actual and predicted 2.0303115844726562F
# 77.02520751953125F is the predicted data the real data is 78.0999984741211F the difference between the actual and predicted 1.0747909545898438F
# 77.71166229248047F is the predicted data the real data is 76.80000305175781F the difference between the actual and predicted -0.9116592407226562F
# 78.39403533935547F is the predicted data the real data is 77.0F the difference between the actual and predicted -1.3940353393554688F
# 79.00397491455078F is the predicted data the real data is 76.9000015258789F the difference between the actual and predicted -2.103973388671875F
# 72.76299285888672F is the predicted data the real data is 71.5F the difference between the actual and predicted -1.2629928588867188F
# 74.8626708984375F is the predicted data the real data is 77.0F the difference between the actual and predicted 2.1373291015625F
# 77.8073959350586F is the predicted data the real data is 76.9000015258789F the difference between the actual and predicted -0.9073944091796875F
# 69.4207992553711F is the predicted data the real data is 67.9000015258789F the difference between the actual and predicted -1.5207977294921875F
# 78.15299224853516F is the predicted data the real data is 77.19999694824219F the difference between the actual and predicted -0.9529953002929688F
# 84.28561401367188F is the predicted data the real data is 83.30000305175781F the difference between the actual and predicted -0.9856109619140625F
# 77.66988372802734F is the predicted data the real data is 76.0F the difference between the actual and predicted -1.6698837280273438F
# 76.52616882324219F is the predicted data the real data is 75.4000015258789F the difference between the actual and predicted -1.1261672973632812F
# 70.55854034423828F is the predicted data the real data is 68.80000305175781F the difference between the actual and predicted -1.7585372924804688F
# 76.72858428955078F is the predicted data the real data is 75.0999984741211F the difference between the actual and predicted -1.6285858154296875F
# 78.25335693359375F is the predicted data the real data is 79.30000305175781F the difference between the actual and predicted 1.0466461181640625F
# 69.51634216308594F is the predicted data the real data is 68.80000305175781F the difference between the actual and predicted -0.716339111328125F
# 69.57769012451172F is the predicted data the real data is 68.0F the difference between the actual and predicted -1.5776901245117188F
# 83.49393463134766F is the predicted data the real data is 81.4000015258789F the difference between the actual and predicted -2.09393310546875F
# 78.46723175048828F is the predicted data the real data is 77.0999984741211F the difference between the actual and predicted -1.3672332763671875F
# 77.4703598022461F is the predicted data the real data is 76.5999984741211F the difference between the actual and predicted -0.870361328125F
# 71.19615936279297F is the predicted data the real data is 70.4000015258789F the difference between the actual and predicted -0.7961578369140625F
# 76.7305679321289F is the predicted data the real data is 75.9000015258789F the difference between the actual and predicted -0.83056640625F
# 76.39395904541016F is the predicted data the real data is 73.69999694824219F the difference between the actual and predicted -2.6939620971679688F
# 76.82218170166016F is the predicted data the real data is 75.80000305175781F the difference between the actual and predicted -1.0221786499023438F
# 83.41944885253906F is the predicted data the real data is 82.4000015258789F the difference between the actual and predicted -1.0194473266601562F
# 84.16019439697266F is the predicted data the real data is 83.0F the difference between the actual and predicted -1.1601943969726562F
# 86.93106842041016F is the predicted data the real data is 85.4000015258789F the difference between the actual and predicted -1.53106689453125F
# 68.8785171508789F is the predicted data the real data is 67.9000015258789F the difference between the actual and predicted -0.978515625F
# 75.0161361694336F is the predicted data the real data is 73.80000305175781F the difference between the actual and predicted -1.2161331176757812F
# 76.64193725585938F is the predicted data the real data is 75.4000015258789F the difference between the actual and predicted -1.2419357299804688F
# 80.71768951416016F is the predicted data the real data is 79.0F the difference between the actual and predicted -1.7176895141601562F
# 82.9435043334961F is the predicted data the real data is 81.80000305175781F the difference between the actual and predicted -1.1435012817382812F
# 75.85425567626953F is the predicted data the real data is 74.19999694824219F the difference between the actual and predicted -1.6542587280273438F
# 77.33991241455078F is the predicted data the real data is 75.5999984741211F the difference between the actual and predicted -1.7399139404296875F
# 75.300537109375F is the predicted data the real data is 74.19999694824219F the difference between the actual and predicted -1.1005401611328125F
# 78.91919708251953F is the predicted data the real data is 76.80000305175781F the difference between the actual and predicted -2.1191940307617188F
# 75.56228637695312F is the predicted data the real data is 74.5F the difference between the actual and predicted -1.062286376953125F
# 77.98029327392578F is the predicted data the real data is 78.9000015258789F the difference between the actual and predicted 0.919708251953125F
# 76.6578598022461F is the predicted data the real data is 75.5999984741211F the difference between the actual and predicted -1.057861328125F
# 65.72718811035156F is the predicted data the real data is 64.80000305175781F the difference between the actual and predicted -0.92718505859375F
# 76.64239501953125F is the predicted data the real data is 74.30000305175781F the difference between the actual and predicted -2.3423919677734375F
# 80.19188690185547F is the predicted data the real data is 77.19999694824219F the difference between the actual and predicted -2.9918899536132812F
# 77.46752166748047F is the predicted data the real data is 75.69999694824219F the difference between the actual and predicted -1.7675247192382812F
# 77.27555084228516F is the predicted data the real data is 76.30000305175781F the difference between the actual and predicted -0.9755477905273438F
# 82.50286102294922F is the predicted data the real data is 81.30000305175781F the difference between the actual and predicted -1.2028579711914062F
# 82.15799713134766F is the predicted data the real data is 81.19999694824219F the difference between the actual and predicted -0.9580001831054688F
# 81.66753387451172F is the predicted data the real data is 80.30000305175781F the difference between the actual and predicted -1.3675308227539062F
# 82.91011047363281F is the predicted data the real data is 81.4000015258789F the difference between the actual and predicted -1.5101089477539062F
# 77.93673706054688F is the predicted data the real data is 79.0F the difference between the actual and predicted 1.063262939453125F
# 70.73271942138672F is the predicted data the real data is 69.69999694824219F the difference between the actual and predicted -1.0327224731445312F
# 80.82240295410156F is the predicted data the real data is 81.9000015258789F the difference between the actual and predicted 1.0775985717773438F
# 72.27034759521484F is the predicted data the real data is 70.9000015258789F the difference between the actual and predicted -1.3703460693359375F
# 84.4053726196289F is the predicted data the real data is 83.19999694824219F the difference between the actual and predicted -1.2053756713867188F
# 77.56087493896484F is the predicted data the real data is 76.0F the difference between the actual and predicted -1.5608749389648438F
# 77.84505462646484F is the predicted data the real data is 76.80000305175781F the difference between the actual and predicted -1.0450515747070312F
# 81.34501647949219F is the predicted data the real data is 82.4000015258789F the difference between the actual and predicted 1.0549850463867188F
# 77.21207427978516F is the predicted data the real data is 75.69999694824219F the difference between the actual and predicted -1.5120773315429688F
# 79.26441192626953F is the predicted data the real data is 80.80000305175781F the difference between the actual and predicted 1.5355911254882812F
# 73.3060531616211F is the predicted data the real data is 72.19999694824219F the difference between the actual and predicted -1.1060562133789062F
# 77.84737396240234F is the predicted data the real data is 76.30000305175781F the difference between the actual and predicted -1.5473709106445312F
# 74.66082000732422F is the predicted data the real data is 70.80000305175781F the difference between the actual and predicted -3.8608169555664062F
# 74.66082000732422F is the predicted data the real data is 70.80000305175781F the difference between the actual and predicted -3.8608169555664062F
# 72.0512466430664F is the predicted data the real data is 71.30000305175781F the difference between the actual and predicted -0.7512435913085938F
# 76.55567932128906F is the predicted data the real data is 75.69999694824219F the difference between the actual and predicted -0.855682373046875F
# 77.30950164794922F is the predicted data the real data is 75.69999694824219F the difference between the actual and predicted -1.6095046997070312F
# 77.0315933227539F is the predicted data the real data is 74.80000305175781F the difference between the actual and predicted -2.2315902709960938F
# 77.0011978149414F is the predicted data the real data is 75.4000015258789F the difference between the actual and predicted -1.6011962890625F
# 77.8584976196289F is the predicted data the real data is 76.80000305175781F the difference between the actual and predicted -1.0584945678710938F
# 68.90113067626953F is the predicted data the real data is 68.0999984741211F the difference between the actual and predicted -0.8011322021484375F
# 88.22180938720703F is the predicted data the real data is 87.30000305175781F the difference between the actual and predicted -0.9218063354492188F
# 74.70313262939453F is the predicted data the real data is 73.5F the difference between the actual and predicted -1.2031326293945312F
# 71.07837677001953F is the predicted data the real data is 69.9000015258789F the difference between the actual and predicted -1.178375244140625F
# 82.07308197021484F is the predicted data the real data is 80.0F the difference between the actual and predicted -2.0730819702148438F
# 79.19196319580078F is the predicted data the real data is 76.80000305175781F the difference between the actual and predicted -2.3919601440429688F
# 78.35336303710938F is the predicted data the real data is 79.5F the difference between the actual and predicted 1.146636962890625F
# 82.721435546875F is the predicted data the real data is 81.80000305175781F the difference between the actual and predicted -0.9214324951171875F
# 77.0347900390625F is the predicted data the real data is 74.5F the difference between the actual and predicted -2.5347900390625F
# 69.28497314453125F is the predicted data the real data is 68.4000015258789F the difference between the actual and predicted -0.8849716186523438F
# 77.22290802001953F is the predicted data the real data is 78.4000015258789F the difference between the actual and predicted 1.177093505859375F
# 75.10395050048828F is the predicted data the real data is 73.5999984741211F the difference between the actual and predicted -1.5039520263671875F
# 77.10303497314453F is the predicted data the real data is 76.19999694824219F the difference between the actual and predicted -0.9030380249023438F
# 75.5147933959961F is the predicted data the real data is 73.5999984741211F the difference between the actual and predicted -1.914794921875F
# 80.3150863647461F is the predicted data the real data is 82.0F the difference between the actual and predicted 1.6849136352539062F
# 77.58580780029297F is the predicted data the real data is 76.0999984741211F the difference between the actual and predicted -1.485809326171875F
# 77.58956909179688F is the predicted data the real data is 76.0F the difference between the actual and predicted -1.589569091796875F
# 78.28288269042969F is the predicted data the real data is 77.19999694824219F the difference between the actual and predicted -1.0828857421875F
# 79.29390716552734F is the predicted data the real data is 78.5F the difference between the actual and predicted -0.7939071655273438F
# 86.37599182128906F is the predicted data the real data is 85.5F the difference between the actual and predicted -0.8759918212890625F
# 84.53812408447266F is the predicted data the real data is 85.9000015258789F the difference between the actual and predicted 1.36187744140625F
# 84.3302230834961F is the predicted data the real data is 82.0F the difference between the actual and predicted -2.3302230834960938F
# 78.49849700927734F is the predicted data the real data is 77.4000015258789F the difference between the actual and predicted -1.0984954833984375F
# 73.44811248779297F is the predicted data the real data is 72.30000305175781F the difference between the actual and predicted -1.1481094360351562F
# 78.4263687133789F is the predicted data the real data is 80.30000305175781F the difference between the actual and predicted 1.8736343383789062F
# 78.73912811279297F is the predicted data the real data is 77.4000015258789F the difference between the actual and predicted -1.3391265869140625F
# 82.99515533447266F is the predicted data the real data is 84.0999984741211F the difference between the actual and predicted 1.1048431396484375F
# 71.46488189697266F is the predicted data the real data is 68.19999694824219F the difference between the actual and predicted -3.2648849487304688F
# 75.71683502197266F is the predicted data the real data is 74.80000305175781F the difference between the actual and predicted -0.9168319702148438F
# 69.25695037841797F is the predicted data the real data is 68.5F the difference between the actual and predicted -0.7569503784179688F
# 69.04208374023438F is the predicted data the real data is 67.80000305175781F the difference between the actual and predicted -1.2420806884765625F
# 82.90657806396484F is the predicted data the real data is 81.5F the difference between the actual and predicted -1.4065780639648438F
# 79.20771026611328F is the predicted data the real data is 78.4000015258789F the difference between the actual and predicted -0.807708740234375F
# 77.17203521728516F is the predicted data the real data is 75.5999984741211F the difference between the actual and predicted -1.5720367431640625F
# 85.00953674316406F is the predicted data the real data is 84.0999984741211F the difference between the actual and predicted -0.9095382690429688F
# 77.11309051513672F is the predicted data the real data is 75.69999694824219F the difference between the actual and predicted -1.4130935668945312F
# 81.0976791381836F is the predicted data the real data is 79.5F the difference between the actual and predicted -1.5976791381835938F
# 74.67046356201172F is the predicted data the real data is 73.0999984741211F the difference between the actual and predicted -1.570465087890625F
# 78.52112579345703F is the predicted data the real data is 79.4000015258789F the difference between the actual and predicted 0.878875732421875F
# 86.74613189697266F is the predicted data the real data is 85.5F the difference between the actual and predicted -1.2461318969726562F
# 77.56896209716797F is the predicted data the real data is 76.5F the difference between the actual and predicted -1.0689620971679688F
# 83.33238220214844F is the predicted data the real data is 81.19999694824219F the difference between the actual and predicted -2.13238525390625F
# 82.44071197509766F is the predicted data the real data is 81.0F the difference between the actual and predicted -1.4407119750976562F
# 78.54778289794922F is the predicted data the real data is 79.5999984741211F the difference between the actual and predicted 1.052215576171875F
# 79.68909454345703F is the predicted data the real data is 78.9000015258789F the difference between the actual and predicted -0.789093017578125F
# 80.58078002929688F is the predicted data the real data is 78.4000015258789F the difference between the actual and predicted -2.1807785034179688F
# 77.43762969970703F is the predicted data the real data is 76.5F the difference between the actual and predicted -0.9376296997070312F
# 80.1769790649414F is the predicted data the real data is 78.9000015258789F the difference between the actual and predicted -1.2769775390625F
# 88.59178161621094F is the predicted data the real data is 87.30000305175781F the difference between the actual and predicted -1.291778564453125F
# 88.2566909790039F is the predicted data the real data is 87.30000305175781F the difference between the actual and predicted -0.9566879272460938F
# 77.24468231201172F is the predicted data the real data is 75.5F the difference between the actual and predicted -1.7446823120117188F
# 76.57506561279297F is the predicted data the real data is 75.5999984741211F the difference between the actual and predicted -0.975067138671875F
# 79.51518249511719F is the predicted data the real data is 78.5F the difference between the actual and predicted -1.0151824951171875F
# 70.17383575439453F is the predicted data the real data is 69.30000305175781F the difference between the actual and predicted -0.8738327026367188F
# 82.5803451538086F is the predicted data the real data is 84.19999694824219F the difference between the actual and predicted 1.6196517944335938F
# 77.9887924194336F is the predicted data the real data is 77.0F the difference between the actual and predicted -0.9887924194335938F
# 79.65128326416016F is the predicted data the real data is 78.80000305175781F the difference between the actual and predicted -0.8512802124023438F
# 77.20481872558594F is the predicted data the real data is 75.80000305175781F the difference between the actual and predicted -1.404815673828125F
# 77.45744323730469F is the predicted data the real data is 76.4000015258789F the difference between the actual and predicted -1.0574417114257812F
# 77.1623764038086F is the predicted data the real data is 75.19999694824219F the difference between the actual and predicted -1.9623794555664062F
# 66.08147430419922F is the predicted data the real data is 63.400001525878906F the difference between the actual and predicted -2.6814727783203125F
# 77.84259796142578F is the predicted data the real data is 77.0F the difference between the actual and predicted -0.8425979614257812F
# 79.39030456542969F is the predicted data the real data is 77.19999694824219F the difference between the actual and predicted -2.1903076171875F
# 74.95095825195312F is the predicted data the real data is 73.5999984741211F the difference between the actual and predicted -1.3509597778320312F
# 80.01044464111328F is the predicted data the real data is 78.9000015258789F the difference between the actual and predicted -1.110443115234375F
# 86.77208709716797F is the predicted data the real data is 84.5F the difference between the actual and predicted -2.2720870971679688F
# 76.54341888427734F is the predicted data the real data is 75.0F the difference between the actual and predicted -1.5434188842773438F
# 77.49585723876953F is the predicted data the real data is 76.4000015258789F the difference between the actual and predicted -1.095855712890625F
# 79.57920837402344F is the predicted data the real data is 77.30000305175781F the difference between the actual and predicted -2.279205322265625F
# 79.78972625732422F is the predicted data the real data is 80.5999984741211F the difference between the actual and predicted 0.810272216796875F
# 77.59540557861328F is the predicted data the real data is 76.5F the difference between the actual and predicted -1.0954055786132812F
# 72.73526000976562F is the predicted data the real data is 71.9000015258789F the difference between the actual and predicted -0.8352584838867188F
# 78.53767395019531F is the predicted data the real data is 76.9000015258789F the difference between the actual and predicted -1.6376724243164062F
# 82.044189453125F is the predicted data the real data is 80.5F the difference between the actual and predicted -1.544189453125F
# 76.38605499267578F is the predicted data the real data is 75.4000015258789F the difference between the actual and predicted -0.986053466796875F
# 76.32630920410156F is the predicted data the real data is 75.4000015258789F the difference between the actual and predicted -0.9263076782226562F
# 69.68302917480469F is the predicted data the real data is 68.5F the difference between the actual and predicted -1.1830291748046875F
# 76.91952514648438F is the predicted data the real data is 75.69999694824219F the difference between the actual and predicted -1.2195281982421875F
# 76.37833404541016F is the predicted data the real data is 75.5999984741211F the difference between the actual and predicted -0.7783355712890625F
# 80.51277160644531F is the predicted data the real data is 78.19999694824219F the difference between the actual and predicted -2.312774658203125F
# 77.06197357177734F is the predicted data the real data is 75.5999984741211F the difference between the actual and predicted -1.46197509765625F
# 82.93658447265625F is the predicted data the real data is 84.0999984741211F the difference between the actual and predicted 1.1634140014648438F
# 83.29187774658203F is the predicted data the real data is 81.19999694824219F the difference between the actual and predicted -2.0918807983398438F
# 68.8375015258789F is the predicted data the real data is 67.80000305175781F the difference between the actual and predicted -1.0374984741210938F
# 83.04782104492188F is the predicted data the real data is 84.19999694824219F the difference between the actual and predicted 1.1521759033203125F
# 70.3783950805664F is the predicted data the real data is 69.30000305175781F the difference between the actual and predicted -1.0783920288085938F
# 78.50328063964844F is the predicted data the real data is 77.30000305175781F the difference between the actual and predicted -1.203277587890625F
# 86.89334869384766F is the predicted data the real data is 87.9000015258789F the difference between the actual and predicted 1.00665283203125F
# 79.51680755615234F is the predicted data the real data is 78.0F the difference between the actual and predicted -1.5168075561523438F
# 67.47884368896484F is the predicted data the real data is 68.5F the difference between the actual and predicted 1.0211563110351562F
# 72.15982818603516F is the predicted data the real data is 70.69999694824219F the difference between the actual and predicted -1.4598312377929688F
# 77.2610855102539F is the predicted data the real data is 74.5F the difference between the actual and predicted -2.7610855102539062F
# 76.8962631225586F is the predicted data the real data is 75.9000015258789F the difference between the actual and predicted -0.9962615966796875F
# 78.13436889648438F is the predicted data the real data is 77.0F the difference between the actual and predicted -1.134368896484375F
# 81.34795379638672F is the predicted data the real data is 80.19999694824219F the difference between the actual and predicted -1.1479568481445312F
# 81.4350357055664F is the predicted data the real data is 80.30000305175781F the difference between the actual and predicted -1.1350326538085938F
# 82.83470916748047F is the predicted data the real data is 83.69999694824219F the difference between the actual and predicted 0.8652877807617188F
# 77.8513412475586F is the predicted data the real data is 76.80000305175781F the difference between the actual and predicted -1.0513381958007812F
# 84.70478057861328F is the predicted data the real data is 83.69999694824219F the difference between the actual and predicted -1.0047836303710938F
# 77.23748016357422F is the predicted data the real data is 75.9000015258789F the difference between the actual and predicted -1.3374786376953125F
# 82.82805633544922F is the predicted data the real data is 81.5F the difference between the actual and predicted -1.3280563354492188F
# 77.8189468383789F is the predicted data the real data is 76.69999694824219F the difference between the actual and predicted -1.1189498901367188F
# 76.83415985107422F is the predicted data the real data is 75.30000305175781F the difference between the actual and predicted -1.5341567993164062F
# 84.56316375732422F is the predicted data the real data is 82.9000015258789F the difference between the actual and predicted -1.6631622314453125F
# 75.7457275390625F is the predicted data the real data is 74.9000015258789F the difference between the actual and predicted -0.8457260131835938F
# 85.21517944335938F is the predicted data the real data is 87.0999984741211F the difference between the actual and predicted 1.8848190307617188F
# 78.50531005859375F is the predicted data the real data is 77.5999984741211F the difference between the actual and predicted -0.9053115844726562F
# 87.08049011230469F is the predicted data the real data is 84.80000305175781F the difference between the actual and predicted -2.280487060546875F
# 84.07109069824219F is the predicted data the real data is 83.0999984741211F the difference between the actual and predicted -0.9710922241210938F
# 75.7154312133789F is the predicted data the real data is 74.5999984741211F the difference between the actual and predicted -1.1154327392578125F
# 83.5062484741211F is the predicted data the real data is 82.4000015258789F the difference between the actual and predicted -1.1062469482421875F
# 86.1294174194336F is the predicted data the real data is 85.19999694824219F the difference between the actual and predicted -0.9294204711914062F
# 81.88739776611328F is the predicted data the real data is 82.9000015258789F the difference between the actual and predicted 1.012603759765625F
# 78.97905731201172F is the predicted data the real data is 80.0999984741211F the difference between the actual and predicted 1.120941162109375F
# 74.48729705810547F is the predicted data the real data is 73.0999984741211F the difference between the actual and predicted -1.387298583984375F
# 69.23063659667969F is the predicted data the real data is 68.5F the difference between the actual and predicted -0.7306365966796875F
# 77.21863555908203F is the predicted data the real data is 75.80000305175781F the difference between the actual and predicted -1.4186325073242188F
# 74.82868194580078F is the predicted data the real data is 73.19999694824219F the difference between the actual and predicted -1.6286849975585938F
# 70.49515533447266F is the predicted data the real data is 69.5999984741211F the difference between the actual and predicted -0.8951568603515625F
# 70.1683578491211F is the predicted data the real data is 69.0999984741211F the difference between the actual and predicted -1.068359375F
# 88.19193267822266F is the predicted data the real data is 87.19999694824219F the difference between the actual and predicted -0.9919357299804688F
# 79.73661041259766F is the predicted data the real data is 78.9000015258789F the difference between the actual and predicted -0.83660888671875F
# 76.85326385498047F is the predicted data the real data is 76.0F the difference between the actual and predicted -0.8532638549804688F
# 78.13689422607422F is the predicted data the real data is 77.19999694824219F the difference between the actual and predicted -0.9368972778320312F
# 79.70787048339844F is the predicted data the real data is 78.9000015258789F the difference between the actual and predicted -0.8078689575195312F
# 77.94567108154297F is the predicted data the real data is 77.0F the difference between the actual and predicted -0.9456710815429688F
# 71.42737579345703F is the predicted data the real data is 72.19999694824219F the difference between the actual and predicted 0.7726211547851562F
# 69.83039093017578F is the predicted data the real data is 68.5F the difference between the actual and predicted -1.3303909301757812F
# 72.99820709228516F is the predicted data the real data is 71.5F the difference between the actual and predicted -1.4982070922851562F
# 75.84490203857422F is the predicted data the real data is 74.5F the difference between the actual and predicted -1.3449020385742188F
# 70.12718200683594F is the predicted data the real data is 69.19999694824219F the difference between the actual and predicted -0.92718505859375F
# 69.22420501708984F is the predicted data the real data is 68.0999984741211F the difference between the actual and predicted -1.12420654296875F
# 86.36721801757812F is the predicted data the real data is 84.80000305175781F the difference between the actual and predicted -1.5672149658203125F
# 80.29908752441406F is the predicted data the real data is 78.80000305175781F the difference between the actual and predicted -1.49908447265625F
# 81.31768035888672F is the predicted data the real data is 79.9000015258789F the difference between the actual and predicted -1.4176788330078125F
# 78.51486206054688F is the predicted data the real data is 77.5F the difference between the actual and predicted -1.014862060546875F
# 83.28894805908203F is the predicted data the real data is 82.4000015258789F the difference between the actual and predicted -0.888946533203125F
# 83.22138977050781F is the predicted data the real data is 84.30000305175781F the difference between the actual and predicted 1.07861328125F
# 78.96074676513672F is the predicted data the real data is 78.0F the difference between the actual and predicted -0.9607467651367188F
# 83.57295989990234F is the predicted data the real data is 82.19999694824219F the difference between the actual and predicted -1.3729629516601562F
# 76.49608612060547F is the predicted data the real data is 74.9000015258789F the difference between the actual and predicted -1.5960845947265625F
# 82.8671646118164F is the predicted data the real data is 81.80000305175781F the difference between the actual and predicted -1.0671615600585938F
# 79.96939849853516F is the predicted data the real data is 78.0999984741211F the difference between the actual and predicted -1.8694000244140625F
# 80.89942932128906F is the predicted data the real data is 77.30000305175781F the difference between the actual and predicted -3.59942626953125F
# 87.9495620727539F is the predicted data the real data is 86.5999984741211F the difference between the actual and predicted -1.3495635986328125F
# 75.85663604736328F is the predicted data the real data is 74.5999984741211F the difference between the actual and predicted -1.2566375732421875F
# 82.05168151855469F is the predicted data the real data is 81.0999984741211F the difference between the actual and predicted -0.9516830444335938F
# 76.27637481689453F is the predicted data the real data is 75.4000015258789F the difference between the actual and predicted -0.876373291015625F
# 85.7837142944336F is the predicted data the real data is 84.5999984741211F the difference between the actual and predicted -1.1837158203125F
# 72.86873626708984F is the predicted data the real data is 71.80000305175781F the difference between the actual and predicted -1.0687332153320312F
# 70.18606567382812F is the predicted data the real data is 68.5F the difference between the actual and predicted -1.686065673828125F
# 76.34266662597656F is the predicted data the real data is 75.5F the difference between the actual and predicted -0.8426666259765625F
# 78.12830352783203F is the predicted data the real data is 79.0F the difference between the actual and predicted 0.8716964721679688F
# 74.20630645751953F is the predicted data the real data is 75.0999984741211F the difference between the actual and predicted 0.8936920166015625F
# 82.54963684082031F is the predicted data the real data is 81.5999984741211F the difference between the actual and predicted -0.9496383666992188F
# 89.03035736083984F is the predicted data the real data is 91.5999984741211F the difference between the actual and predicted 2.56964111328125F
# 77.23527526855469F is the predicted data the real data is 75.80000305175781F the difference between the actual and predicted -1.435272216796875F
# 76.86792755126953F is the predicted data the real data is 75.69999694824219F the difference between the actual and predicted -1.1679306030273438F
# 85.78949737548828F is the predicted data the real data is 84.69999694824219F the difference between the actual and predicted -1.0895004272460938F
# 70.52100372314453F is the predicted data the real data is 69.5F the difference between the actual and predicted -1.0210037231445312F
# 79.08807373046875F is the predicted data the real data is 78.0999984741211F the difference between the actual and predicted -0.9880752563476562F
# 77.59612274169922F is the predicted data the real data is 76.80000305175781F the difference between the actual and predicted -0.7961196899414062F
# 82.30916595458984F is the predicted data the real data is 83.5F the difference between the actual and predicted 1.1908340454101562F
# 78.88895416259766F is the predicted data the real data is 76.80000305175781F the difference between the actual and predicted -2.0889511108398438F
# 70.22093200683594F is the predicted data the real data is 68.69999694824219F the difference between the actual and predicted -1.52093505859375F
# 70.40067291259766F is the predicted data the real data is 69.30000305175781F the difference between the actual and predicted -1.1006698608398438F
# 76.78421783447266F is the predicted data the real data is 75.80000305175781F the difference between the actual and predicted -0.9842147827148438F
# 77.00157928466797F is the predicted data the real data is 74.0999984741211F the difference between the actual and predicted -2.901580810546875F
# 75.8296890258789F is the predicted data the real data is 74.80000305175781F the difference between the actual and predicted -1.0296859741210938F
# 82.15715789794922F is the predicted data the real data is 83.19999694824219F the difference between the actual and predicted 1.0428390502929688F
# 82.56055450439453F is the predicted data the real data is 81.0F the difference between the actual and predicted -1.5605545043945312F
# 79.8676528930664F is the predicted data the real data is 78.80000305175781F the difference between the actual and predicted -1.0676498413085938F
# 80.02027130126953F is the predicted data the real data is 78.80000305175781F the difference between the actual and predicted -1.2202682495117188F
# 69.61209869384766F is the predicted data the real data is 68.5F the difference between the actual and predicted -1.1120986938476562F
# 80.10774993896484F is the predicted data the real data is 78.0F the difference between the actual and predicted -2.1077499389648438F
# 75.99185180664062F is the predicted data the real data is 74.4000015258789F the difference between the actual and predicted -1.5918502807617188F
# 77.66117095947266F is the predicted data the real data is 76.69999694824219F the difference between the actual and predicted -0.9611740112304688F
# 86.22779083251953F is the predicted data the real data is 84.5999984741211F the difference between the actual and predicted -1.6277923583984375F
# 77.41584014892578F is the predicted data the real data is 76.30000305175781F the difference between the actual and predicted -1.1158370971679688F
# 63.920616149902344F is the predicted data the real data is 62.5F the difference between the actual and predicted -1.4206161499023438F
# 68.94342803955078F is the predicted data the real data is 68.0F the difference between the actual and predicted -0.9434280395507812F
# 81.49690246582031F is the predicted data the real data is 80.4000015258789F the difference between the actual and predicted -1.0969009399414062F
# 78.15848541259766F is the predicted data the real data is 77.19999694824219F the difference between the actual and predicted -0.9584884643554688F
# 82.55519104003906F is the predicted data the real data is 81.69999694824219F the difference between the actual and predicted -0.855194091796875F
# ...
# 77.37169647216797F is the predicted data the real data is 74.5F the difference between the actual and predicted -2.8716964721679688F
# 79.66404724121094F is the predicted data the real data is 78.69999694824219F the difference between the actual and predicted -0.96405029296875F
# 70.9238510131836F is the predicted data the real data is 69.4000015258789F the difference between the actual and predicted -1.5238494873046875F
# 71.5957260131836F is the predicted data the real data is 70.80000305175781F the difference between the actual and predicted -0.7957229614257812F
# 81.85912322998047F is the predicted data the real data is 80.4000015258789F the difference between the actual and predicted -1.4591217041015625F
# 87.38765716552734F is the predicted data the real data is 88.30000305175781F the difference between the actual and predicted 0.9123458862304688F
# 78.82685089111328F is the predicted data the real data is 78.0F the difference between the actual and predicted -0.8268508911132812F
# 80.82527923583984F is the predicted data the real data is 78.9000015258789F the difference between the actual and predicted -1.9252777099609375F
# 74.63790130615234F is the predicted data the real data is 73.30000305175781F the difference between the actual and predicted -1.3378982543945312F
# 80.3957290649414F is the predicted data the real data is 79.5F the difference between the actual and predicted -0.8957290649414062F
# 77.65283966064453F is the predicted data the real data is 76.69999694824219F the difference between the actual and predicted -0.9528427124023438F
# 82.63075256347656F is the predicted data the real data is 81.80000305175781F the difference between the actual and predicted -0.83074951171875F
# 74.71495056152344F is the predicted data the real data is 73.5F the difference between the actual and predicted -1.2149505615234375F
# 79.635986328125F is the predicted data the real data is 78.80000305175781F the difference between the actual and predicted -0.8359832763671875F
# 77.31970977783203F is the predicted data the real data is 75.69999694824219F the difference between the actual and predicted -1.6197128295898438F
# 78.2505874633789F is the predicted data the real data is 76.5F the difference between the actual and predicted -1.7505874633789062F
# 69.07490539550781F is the predicted data the real data is 68.0999984741211F the difference between the actual and predicted -0.9749069213867188F
# 77.93667602539062F is the predicted data the real data is 77.0999984741211F the difference between the actual and predicted -0.8366775512695312F
# 77.33919525146484F is the predicted data the real data is 76.5F the difference between the actual and predicted -0.8391952514648438F
# 71.76349639892578F is the predicted data the real data is 72.5999984741211F the difference between the actual and predicted 0.8365020751953125F
# 84.17110443115234F is the predicted data the real data is 82.5999984741211F the difference between the actual and predicted -1.57110595703125F
# 83.09362030029297F is the predicted data the real data is 84.19999694824219F the difference between the actual and predicted 1.1063766479492188F
# 80.98180389404297F is the predicted data the real data is 79.4000015258789F the difference between the actual and predicted -1.5818023681640625F
# 77.0860595703125F is the predicted data the real data is 75.4000015258789F the difference between the actual and predicted -1.6860580444335938F
# 84.64671325683594F is the predicted data the real data is 83.80000305175781F the difference between the actual and predicted -0.846710205078125F
# 69.26536560058594F is the predicted data the real data is 68.0999984741211F the difference between the actual and predicted -1.1653671264648438F
# 78.76107788085938F is the predicted data the real data is 79.9000015258789F the difference between the actual and predicted 1.1389236450195312F
# 84.05323791503906F is the predicted data the real data is 82.9000015258789F the difference between the actual and predicted -1.1532363891601562F
# 77.21004486083984F is the predicted data the real data is 74.5999984741211F the difference between the actual and predicted -2.61004638671875F
# 88.60003662109375F is the predicted data the real data is 87.4000015258789F the difference between the actual and predicted -1.2000350952148438F
# 80.70616912841797F is the predicted data the real data is 79.9000015258789F the difference between the actual and predicted -0.8061676025390625F
# 69.34514617919922F is the predicted data the real data is 68.0999984741211F the difference between the actual and predicted -1.245147705078125F
# 75.07431030273438F is the predicted data the real data is 73.69999694824219F the difference between the actual and predicted -1.3743133544921875F
# 77.99351501464844F is the predicted data the real data is 77.0999984741211F the difference between the actual and predicted -0.8935165405273438F
# 72.80746459960938F is the predicted data the real data is 71.80000305175781F the difference between the actual and predicted -1.0074615478515625F
# 76.01263427734375F is the predicted data the real data is 74.9000015258789F the difference between the actual and predicted -1.1126327514648438F
# 78.24504852294922F is the predicted data the real data is 77.19999694824219F the difference between the actual and predicted -1.0450515747070312F
# 85.00081634521484F is the predicted data the real data is 86.5999984741211F the difference between the actual and predicted 1.59918212890625F
# 69.35820770263672F is the predicted data the real data is 67.9000015258789F the difference between the actual and predicted -1.4582061767578125F
# 82.44860076904297F is the predicted data the real data is 81.5999984741211F the difference between the actual and predicted -0.848602294921875F
# 64.8193359375F is the predicted data the real data is 63.099998474121094F the difference between the actual and predicted -1.7193374633789062F
# 82.13019561767578F is the predicted data the real data is 81.19999694824219F the difference between the actual and predicted -0.9301986694335938F
# 77.47492218017578F is the predicted data the real data is 79.5F the difference between the actual and predicted 2.0250778198242188F
# 68.52835083007812F is the predicted data the real data is 67.80000305175781F the difference between the actual and predicted -0.7283477783203125F
# 77.41477966308594F is the predicted data the real data is 76.5F the difference between the actual and predicted -0.9147796630859375F
# 78.44029998779297F is the predicted data the real data is 79.30000305175781F the difference between the actual and predicted 0.8597030639648438F
# 78.0484619140625F is the predicted data the real data is 76.9000015258789F the difference between the actual and predicted -1.1484603881835938F
# 79.75659942626953F is the predicted data the real data is 78.30000305175781F the difference between the actual and predicted -1.4565963745117188F
# 77.23018646240234F is the predicted data the real data is 76.4000015258789F the difference between the actual and predicted -0.8301849365234375F
# 77.35070037841797F is the predicted data the real data is 76.30000305175781F the difference between the actual and predicted -1.0506973266601562F
# 70.41841125488281F is the predicted data the real data is 69.30000305175781F the difference between the actual and predicted -1.118408203125F
# 78.40743255615234F is the predicted data the real data is 77.0F the difference between the actual and predicted -1.4074325561523438F
# 76.68893432617188F is the predicted data the real data is 75.4000015258789F the difference between the actual and predicted -1.2889328002929688F
# 67.03716278076172F is the predicted data the real data is 68.19999694824219F the difference between the actual and predicted 1.1628341674804688F
# 77.2191390991211F is the predicted data the real data is 75.69999694824219F the difference between the actual and predicted -1.5191421508789062F
# 77.1762466430664F is the predicted data the real data is 74.80000305175781F the difference between the actual and predicted -2.3762435913085938F
# 77.47045135498047F is the predicted data the real data is 75.80000305175781F the difference between the actual and predicted -1.6704483032226562F
# 69.81134033203125F is the predicted data the real data is 68.5F the difference between the actual and predicted -1.31134033203125F
# 77.40812683105469F is the predicted data the real data is 73.5F the difference between the actual and predicted -3.9081268310546875F
# 77.40812683105469F is the predicted data the real data is 73.5F the difference between the actual and predicted -3.9081268310546875F
# 78.68608856201172F is the predicted data the real data is 77.4000015258789F the difference between the actual and predicted -1.2860870361328125F
# 79.45768737792969F is the predicted data the real data is 78.5F the difference between the actual and predicted -0.9576873779296875F
# 75.55628204345703F is the predicted data the real data is 74.80000305175781F the difference between the actual and predicted -0.7562789916992188F
# 70.22283172607422F is the predicted data the real data is 69.5F the difference between the actual and predicted -0.7228317260742188F
# 80.56566619873047F is the predicted data the real data is 78.30000305175781F the difference between the actual and predicted -2.2656631469726562F
# 77.83519744873047F is the predicted data the real data is 79.0999984741211F the difference between the actual and predicted 1.264801025390625F
# 69.41165924072266F is the predicted data the real data is 68.30000305175781F the difference between the actual and predicted -1.1116561889648438F
# 63.43391418457031F is the predicted data the real data is 62.099998474121094F the difference between the actual and predicted -1.3339157104492188F
# 79.79546356201172F is the predicted data the real data is 77.5F the difference between the actual and predicted -2.2954635620117188F
# 76.99227142333984F is the predicted data the real data is 75.80000305175781F the difference between the actual and predicted -1.1922683715820312F
# 77.28560638427734F is the predicted data the real data is 75.19999694824219F the difference between the actual and predicted -2.0856094360351562F
# 79.29471588134766F is the predicted data the real data is 78.19999694824219F the difference between the actual and predicted -1.0947189331054688F
# 79.50777435302734F is the predicted data the real data is 78.5999984741211F the difference between the actual and predicted -0.90777587890625F
# 80.64151763916016F is the predicted data the real data is 78.5999984741211F the difference between the actual and predicted -2.0415191650390625F
# 80.8526840209961F is the predicted data the real data is 81.69999694824219F the difference between the actual and predicted 0.8473129272460938F
# 78.5824966430664F is the predicted data the real data is 77.30000305175781F the difference between the actual and predicted -1.2824935913085938F
# 79.26532745361328F is the predicted data the real data is 77.19999694824219F the difference between the actual and predicted -2.0653305053710938F
# 76.42190551757812F is the predicted data the real data is 74.0F the difference between the actual and predicted -2.421905517578125F
# 84.16109466552734F is the predicted data the real data is 83.0999984741211F the difference between the actual and predicted -1.06109619140625F
# 76.2550277709961F is the predicted data the real data is 73.19999694824219F the difference between the actual and predicted -3.0550308227539062F
# 83.9125747680664F is the predicted data the real data is 82.0999984741211F the difference between the actual and predicted -1.8125762939453125F
# 70.1714096069336F is the predicted data the real data is 69.4000015258789F the difference between the actual and predicted -0.7714080810546875F
# 79.96387481689453F is the predicted data the real data is 77.4000015258789F the difference between the actual and predicted -2.563873291015625F
# 77.20784759521484F is the predicted data the real data is 75.69999694824219F the difference between the actual and predicted -1.5078506469726562F
# 80.35240936279297F is the predicted data the real data is 79.5F the difference between the actual and predicted -0.8524093627929688F
# 80.6769027709961F is the predicted data the real data is 78.80000305175781F the difference between the actual and predicted -1.8768997192382812F
# 65.65483856201172F is the predicted data the real data is 64.80000305175781F the difference between the actual and predicted -0.8548355102539062F
# 77.0508041381836F is the predicted data the real data is 76.19999694824219F the difference between the actual and predicted -0.8508071899414062F
# 83.67021179199219F is the predicted data the real data is 82.69999694824219F the difference between the actual and predicted -0.97021484375F
# 65.97603607177734F is the predicted data the real data is 64.80000305175781F the difference between the actual and predicted -1.1760330200195312F
# 69.63581085205078F is the predicted data the real data is 68.5F the difference between the actual and predicted -1.1358108520507812F
# 73.80640411376953F is the predicted data the real data is 72.80000305175781F the difference between the actual and predicted -1.0064010620117188F
# 68.97374725341797F is the predicted data the real data is 68.0F the difference between the actual and predicted -0.9737472534179688F
# 81.38909912109375F is the predicted data the real data is 80.5F the difference between the actual and predicted -0.88909912109375F
# 71.53142547607422F is the predicted data the real data is 70.19999694824219F the difference between the actual and predicted -1.3314285278320312F
# 76.16275787353516F is the predicted data the real data is 75.4000015258789F the difference between the actual and predicted -0.76275634765625F
# 75.88602447509766F is the predicted data the real data is 75.0F the difference between the actual and predicted -0.8860244750976562F
# 78.53266143798828F is the predicted data the real data is 79.69999694824219F the difference between the actual and predicted 1.1673355102539062F
# 86.4840316772461F is the predicted data the real data is 84.80000305175781F the difference between the actual and predicted -1.6840286254882812F
# 78.22374725341797F is the predicted data the real data is 77.30000305175781F the difference between the actual and predicted -0.9237442016601562F
# 76.95254516601562F is the predicted data the real data is 74.69999694824219F the difference between the actual and predicted -2.2525482177734375F
# 79.27904510498047F is the predicted data the real data is 78.19999694824219F the difference between the actual and predicted -1.0790481567382812F
# 77.22835540771484F is the predicted data the real data is 75.80000305175781F the difference between the actual and predicted -1.4283523559570312F
# 77.37206268310547F is the predicted data the real data is 75.69999694824219F the difference between the actual and predicted -1.6720657348632812F
# 68.88887786865234F is the predicted data the real data is 67.80000305175781F the difference between the actual and predicted -1.0888748168945312F
# 78.25228118896484F is the predicted data the real data is 76.69999694824219F the difference between the actual and predicted -1.5522842407226562F
# 76.46918487548828F is the predicted data the real data is 75.69999694824219F the difference between the actual and predicted -0.7691879272460938F
# 77.02812957763672F is the predicted data the real data is 75.69999694824219F the difference between the actual and predicted -1.3281326293945312F
# 76.4419937133789F is the predicted data the real data is 74.4000015258789F the difference between the actual and predicted -2.0419921875F
# 79.5949935913086F is the predicted data the real data is 80.80000305175781F the difference between the actual and predicted 1.2050094604492188F
# 77.69097137451172F is the predicted data the real data is 76.69999694824219F the difference between the actual and predicted -0.9909744262695312F
# Training data amount: 1967
# 10 is outside of 5% (0.5083884087442806%)
# 918 is outside of 1% (46.67005592272496%)
# 1.3518116474151611 is the MSE
